# %%
import pandas as pd

# %%
df = pd.read_csv("/Users/jastisarika/Downloads/data_jobs.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 785741 entries, 0 to 785740
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   job_title_short        785741 non-null  object
#  1   job_title              785740 non-null  object
#  2   job_location           784696 non-null  object
#  3   job_via                785733 non-null  object
#  4   job_schedule_type      773074 non-null  object
#  5   job_work_from_home     785741 non-null  bool
#  6   search_location        785741 non-null  object
#  7   job_posted_date        785741 non-null  object
#  8   job_no_degree_mention  785741 non-null  bool
#  9   job_health_insurance   785741 non-null  bool
#  10  job_country            785692 non-null  object
#  11  salary_rate            33067 non-null   object
#  12  salary_year_avg        22003 non-null   float64
#  13  salary_hour_avg        10662 non-null   float64
# ...

# %%
df["job_posted_date"] = pd.to_datetime(df.job_posted_date)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 785741 entries, 0 to 785740
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   job_title_short        785741 non-null  object
#  1   job_title              785740 non-null  object
#  2   job_location           784696 non-null  object
#  3   job_via                785733 non-null  object
#  4   job_schedule_type      773074 non-null  object
#  5   job_work_from_home     785741 non-null  bool
#  6   search_location        785741 non-null  object
#  7   job_posted_date        785741 non-null  datetime64[ns]
#  8   job_no_degree_mention  785741 non-null  bool
#  9   job_health_insurance   785741 non-null  bool
#  10  job_country            785692 non-null  object
#  11  salary_rate            33067 non-null   object
#  12  salary_year_avg        22003 non-null   float64
#  13  salary_hour_avg        10662 non-null   float64
# ...

# %%
df["Job_posted_month"] = df.job_posted_date.dt.month

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 785741 entries, 0 to 785740
# Data columns (total 19 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   job_title_short        785741 non-null  object
#  1   job_title              785740 non-null  object
#  2   job_location           784696 non-null  object
#  3   job_via                785733 non-null  object
#  4   job_schedule_type      773074 non-null  object
#  5   job_work_from_home     785741 non-null  bool
#  6   search_location        785741 non-null  object
#  7   job_posted_date        785741 non-null  datetime64[ns]
#  8   job_no_degree_mention  785741 non-null  bool
#  9   job_health_insurance   785741 non-null  bool
#  10  job_country            785692 non-null  object
#  11  salary_rate            33067 non-null   object
#  12  salary_year_avg        22003 non-null   float64
#  13  salary_hour_avg        10662 non-null   float64
# ...

# %%
df.drop(labels="ob_posted_month",axis = 1,inplace =True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 785741 entries, 0 to 785740
# Data columns (total 18 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   job_title_short        785741 non-null  object
#  1   job_title              785740 non-null  object
#  2   job_location           784696 non-null  object
#  3   job_via                785733 non-null  object
#  4   job_schedule_type      773074 non-null  object
#  5   job_work_from_home     785741 non-null  bool
#  6   search_location        785741 non-null  object
#  7   job_posted_date        785741 non-null  datetime64[ns]
#  8   job_no_degree_mention  785741 non-null  bool
#  9   job_health_insurance   785741 non-null  bool
#  10  job_country            785692 non-null  object
#  11  salary_rate            33067 non-null   object
#  12  salary_year_avg        22003 non-null   float64
#  13  salary_hour_avg        10662 non-null   float64
# ...

# %%
df.drop(labels="salary_hour_avg",axis = 1,inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 785741 entries, 0 to 785740
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   job_title_short        785741 non-null  object
#  1   job_title              785740 non-null  object
#  2   job_location           784696 non-null  object
#  3   job_via                785733 non-null  object
#  4   job_schedule_type      773074 non-null  object
#  5   job_work_from_home     785741 non-null  bool
#  6   search_location        785741 non-null  object
#  7   job_posted_date        785741 non-null  datetime64[ns]
#  8   job_no_degree_mention  785741 non-null  bool
#  9   job_health_insurance   785741 non-null  bool
#  10  job_country            785692 non-null  object
#  11  salary_rate            33067 non-null   object
#  12  salary_year_avg        22003 non-null   float64
#  13  company_name           785723 non-null  object
# ...

# %%
df.describe()
# Out:
#                      job_posted_date  salary_year_avg  Job_posted_month
# count                         785741     22003.000000     785741.000000
# mean   2023-06-25 16:02:11.860248576    123286.274072          6.305538
# min              2023-01-01 00:00:04     15000.000000          1.000000
# 25%              2023-03-20 10:05:48     90000.000000          3.000000
# 50%              2023-06-29 06:11:38    115000.000000          6.000000
# 75%              2023-09-27 01:01:16    150000.000000          9.000000
# max              2023-12-31 23:59:58    960000.000000         12.000000
# std                              NaN     48312.449482          3.525408

# %%
# here if we see that min salary per year is only 15000, we have to find that whether this really 15000 or entered by mistake as 15000 
#letsinvestiagte that minimum vale
#go to that vale by accessing its index
df["salary_year_avg"].min()
# Out:
# 15000.0

# %%
# so we know that there is a value of 15000, but we have ti know in which index value it is there
df["salary_year_avg"].idxmin()
# Out:
# 665729

# %%
min_value = df["salary_year_avg"].idxmin()
df.iloc[min_value]
#so we have to use iloc to locate that value 
#so investiagte by using cahtgpt or other resources whether this is true or data emtry mistake or why it is there
# Out:
# job_title_short                                              Data Engineer
# job_title                                           Data Engineer - Hadoop
# job_location                                                        Brazil
# job_via                                                       via LinkedIn
# job_schedule_type                                                Full-time
# job_work_from_home                                                   False
# search_location                                                     Brazil
# job_posted_date                                        2023-12-09 10:05:30
# job_no_degree_mention                                                 True
# job_health_insurance                                                 False
# job_country                                                         Brazil
# salary_rate                                                           year
# ...

# %%
df["job_title_short"].unique()
# Out:
# array(['Senior Data Engineer', 'Data Analyst', 'Data Engineer',
#        'Business Analyst', 'Data Scientist', 'Machine Learning Engineer',
#        'Senior Data Analyst', 'Cloud Engineer', 'Senior Data Scientist',
#        'Software Engineer'], dtype=object)

# %%
df["job_title_short"].value_counts()
# Out:
# job_title_short
# Data Analyst                 196075
# Data Engineer                186241
# Data Scientist               172286
# Business Analyst              49063
# Software Engineer             44929
# Senior Data Engineer          44563
# Senior Data Scientist         36957
# Senior Data Analyst           29216
# Machine Learning Engineer     14080
# Cloud Engineer                12331
# Name: count, dtype: int64

# %%
df.groupby('job_title_short')['salary_year_avg'].min()
# Out:
# job_title_short
# Business Analyst             16500.0
# Cloud Engineer               42000.0
# Data Analyst                 25000.0
# Data Engineer                15000.0
# Data Scientist               27000.0
# Machine Learning Engineer    30000.0
# Senior Data Analyst          30000.0
# Senior Data Engineer         35000.0
# Senior Data Scientist        45000.0
# Software Engineer            28000.0
# Name: salary_year_avg, dtype: float64

# %%
df.groupby('job_title_short')['salary_year_avg'].median()
# Out:
# job_title_short
# Business Analyst              85000.0
# Cloud Engineer                90000.0
# Data Analyst                  90000.0
# Data Engineer                125000.0
# Data Scientist               127500.0
# Machine Learning Engineer    106415.0
# Senior Data Analyst          111175.0
# Senior Data Engineer         147500.0
# Senior Data Scientist        155500.0
# Software Engineer             99150.0
# Name: salary_year_avg, dtype: float64

# %%
df.groupby('job_title_short')['salary_year_avg'].agg(["min","max","median"])
# Out:
#                                min       max    median
# job_title_short
# Business Analyst           16500.0  387460.0   85000.0
# Cloud Engineer             42000.0  280000.0   90000.0
# Data Analyst               25000.0  650000.0   90000.0
# Data Engineer              15000.0  525000.0  125000.0
# Data Scientist             27000.0  960000.0  127500.0
# Machine Learning Engineer  30000.0  325000.0  106415.0
# Senior Data Analyst        30000.0  425000.0  111175.0
# Senior Data Engineer       35000.0  425000.0  147500.0
# Senior Data Scientist      45000.0  890000.0  155500.0
# Software Engineer          28000.0  375000.0   99150.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 785741 entries, 0 to 785740
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   job_title_short        785741 non-null  object
#  1   job_title              785740 non-null  object
#  2   job_location           784696 non-null  object
#  3   job_via                785733 non-null  object
#  4   job_schedule_type      773074 non-null  object
#  5   job_work_from_home     785741 non-null  bool
#  6   search_location        785741 non-null  object
#  7   job_posted_date        785741 non-null  datetime64[ns]
#  8   job_no_degree_mention  785741 non-null  bool
#  9   job_health_insurance   785741 non-null  bool
#  10  job_country            785692 non-null  object
#  11  salary_rate            33067 non-null   object
#  12  salary_year_avg        22003 non-null   float64
#  13  company_name           785723 non-null  object
# ...

# %%
# we want to see what different countries are available and also any country in particular
df['job_country'].value_counts()
# Out:
# job_country
# United States     206292
# India              51088
# United Kingdom     40375
# France             39922
# Germany            27694
#                    ...
# Guinea                 4
# Mauritania             3
# Lesotho                3
# Bhutan                 3
# Maldives               2
# Name: count, Length: 160, dtype: int64

# %%
# as u can see it is not that helpful, lets dig in to it to see country bazil if it is available in top 20,
# lets see top head
df['job_country'].value_counts().head(20)
# Out:
# job_country
# United States     206292
# India              51088
# United Kingdom     40375
# France             39922
# Germany            27694
# Spain              25100
# Singapore          23696
# Sudan              21781
# Netherlands        20631
# Italy              17013
# Canada             16029
# Mexico             15139
# Poland             14793
# Portugal           14508
# Australia          12955
# South Africa       12414
# Belgium            12078
# Philippines        11786
# Ireland            11162
# Switzerland         9924
# Name: count, dtype: int64

# %%
# as we cannot see lets mention the country wether it is in the list 
df['job_country'].isin(['Brazil'])
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 785736    False
# 785737    False
# 785738    False
# 785739    False
# 785740    False
# Name: job_country, Length: 785741, dtype: bool

# %%
#we are getting boolean values, which is not helpful,,, lets find any of the values is brazil?
df['job_country'].isin(['Brazil']).any()
# Out:
# True

# %%
# another example-lets see for the country that is not present
df['job_country'].isin(["north korea"]).any()
# Out:
# False

# %%
#we need to create a new df with a country of choice to analyse further
us_jobs = df[df["job_country"]=="United States"]

# %%
us_jobs.head()  #now we have filtered the data. now we have
#to check what we want to calculate median, min lie that and if there are any nan values.
# Out:
#         job_title_short                                          job_title  \
# 0  Senior Data Engineer  Senior Clinical Data Engineer / Principal Clin...
# 3         Data Engineer  LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 5         Data Engineer                                  GCP Data Engineer
# 6  Senior Data Engineer                  Senior Data Engineer  - GCP Cloud
# 9        Data Scientist                                  Data Scientist II
#
#       job_location            job_via         job_schedule_type  \
# 0    Watertown, CT    via Work Nearby                 Full-time
# 3  San Antonio, TX  via Diversity.com                 Full-time
# 5         Anywhere   via ZipRecruiter  Contractor and Temp work
# 6     Dearborn, MI       via LinkedIn                 Full-time
# 9         Anywhere   via ZipRecruiter                 Full-time
#
#    job_work_from_home          search_location     job_posted_date  \
# ...

# %%
#as u can see there are nan values in the salary avg column , for which we have cal agg , we have to keep the data which are notna..
# so apply notna method on the dataframe and use itprint(us_jobs.columns)

# %%
us_jobs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 206292 entries, 0 to 785705
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   job_title_short        206292 non-null  object
#  1   job_title              206292 non-null  object
#  2   job_location           205505 non-null  object
#  3   job_via                206285 non-null  object
#  4   job_schedule_type      205099 non-null  object
#  5   job_work_from_home     206292 non-null  bool
#  6   search_location        206292 non-null  object
#  7   job_posted_date        206292 non-null  datetime64[ns]
#  8   job_no_degree_mention  206292 non-null  bool
#  9   job_health_insurance   206292 non-null  bool
#  10  job_country            206292 non-null  object
#  11  salary_rate            25372 non-null   object
#  12  salary_year_avg        15766 non-null   float64
#  13  company_name           206292 non-null  object
# ...

# %%
us_jobs = us_jobs[us_jobs['salary_year_avg'].notna()]

# %%
us_jobs.head()
# Out:
#     job_title_short                                          job_title  \
# 92    Data Engineer            Remote - Data Engineer - Permanent - W2
# 100  Data Scientist            Data Scientist, Risk Data Mining - USDS
# 109    Data Analyst              Senior Supply Chain Analytics Analyst
# 116  Data Scientist                                     Data Scientist
# 146   Data Engineer  Data Engineer Graduate (Real Time Communicatio...
#
#           job_location       job_via job_schedule_type  job_work_from_home  \
# 92            Anywhere  via LinkedIn         Full-time                True
# 100  Mountain View, CA  via LinkedIn         Full-time               False
# 109           Anywhere    via Get.It         Full-time                True
# 116           Anywhere  via LinkedIn         Full-time                True
# 146        Seattle, WA  via LinkedIn         Full-time               False
#
#                search_location     job_posted_date  job_no_degree_mention  \
# ...

# %%
us_jobs.groupby('job_title_short')['salary_year_avg'].agg(['median','min','max']).sort_values(by ='median',ascending = False)
# Out:
#                              median      min       max
# job_title_short
# Senior Data Scientist      155000.0  55000.0  475000.0
# Machine Learning Engineer  150000.0  44408.5  315000.0
# Senior Data Engineer       150000.0  45000.0  375000.0
# Data Scientist             130000.0  30000.0  960000.0
# Software Engineer          130000.0  48982.0  375000.0
# Data Engineer              125000.0  23496.0  525000.0
# Cloud Engineer             116100.0  42000.0  221844.0
# Senior Data Analyst        110000.0  35360.0  425000.0
# Business Analyst            90000.0  35000.0  387460.0
# Data Analyst                90000.0  25000.0  375000.0

# %%
import matplotlib.pyplot as plt

# %%
#line chart - trend 
#bar chart - 2 a
#first chart - 
a =[1,2,3,4]
b= [1,2,3,4]
plt.plot(a,b)
plt.show()

# %%
#plotting  how many job postings are happening wrt dates.in order to to tha, 
#first we should know how many jobs are posted for each date ..that means, for each unique value in date column, 
#we have to find no of times that value is given..we have to count the unique valuess
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 785741 entries, 0 to 785740
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   job_title_short        785741 non-null  object
#  1   job_title              785740 non-null  object
#  2   job_location           784696 non-null  object
#  3   job_via                785733 non-null  object
#  4   job_schedule_type      773074 non-null  object
#  5   job_work_from_home     785741 non-null  bool
#  6   search_location        785741 non-null  object
#  7   job_posted_date        785741 non-null  datetime64[ns]
#  8   job_no_degree_mention  785741 non-null  bool
#  9   job_health_insurance   785741 non-null  bool
#  10  job_country            785692 non-null  object
#  11  salary_rate            33067 non-null   object
#  12  salary_year_avg        22003 non-null   float64
#  13  company_name           785723 non-null  object
# ...

# %%
date_counts = df.job_posted_date.value_counts()

# %%
plt.plot(date_counts)
plt.show()

# %%
# # if we see, this is a messy plot because,plot(date_counts) takes dates on x axis and counts on y axis ,.. 
# also if we investigate further, date value has timevalues also .. so we need to figure out how to plot for that, 
# we need to clean the data and bring a new column- day or month column to plot

# %%
df
# Out:
#              job_title_short  \
# 0       Senior Data Engineer
# 1               Data Analyst
# 2              Data Engineer
# 3              Data Engineer
# 4              Data Engineer
# ...                      ...
# 785736     Software Engineer
# 785737          Data Analyst
# 785738      Business Analyst
# 785739         Data Engineer
# 785740     Software Engineer
#
#                                                 job_title  \
# 0       Senior Clinical Data Engineer / Principal Clin...
# 1                                            Data Analyst
# 2       Data Engineer/Scientist/Analyst, Mid or Senior...
# 3       LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4                                  Data Engineer- Sr Jobs
# ...                                                   ...
# 785736                                    DevOps Engineer
# 785737                                   CRM Data Analyst
# 785738                     Commercial Analyst - Start Now
# ...

# %%
monthly_counts.index = pd.to_datetime(monthly_counts.index)

# %%
type(monthly_counts)
# Out:
# pandas.core.series.Series

# %%
plt.plot(monthly_counts.index, monthly_counts, marker='o', linestyle='-', color='blue')

# %%
print(monthly_counts)
# Out:
# job_posted_month
# 1970-01-01 00:00:00.000000001    91822
# 1970-01-01 00:00:00.000000008    75162
# 1970-01-01 00:00:00.000000010    66611
# 1970-01-01 00:00:00.000000002    64578
# 1970-01-01 00:00:00.000000011    64450
# 1970-01-01 00:00:00.000000003    64084
# 1970-01-01 00:00:00.000000007    63777
# 1970-01-01 00:00:00.000000004    62919
# 1970-01-01 00:00:00.000000009    62359
# 1970-01-01 00:00:00.000000006    61572
# 1970-01-01 00:00:00.000000012    56303
# 1970-01-01 00:00:00.000000005    52104
# Name: count, dtype: int64

# %%
df.head()
# Out:
#         job_title_short                                          job_title  \
# 0  Senior Data Engineer  Senior Clinical Data Engineer / Principal Clin...
# 1          Data Analyst                                       Data Analyst
# 2         Data Engineer  Data Engineer/Scientist/Analyst, Mid or Senior...
# 3         Data Engineer  LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4         Data Engineer                             Data Engineer- Sr Jobs
#
#                    job_location             job_via job_schedule_type  \
# 0                 Watertown, CT     via Work Nearby         Full-time
# 1  Guadalajara, Jalisco, Mexico    via BeBee México         Full-time
# 2               Berlin, Germany        via LinkedIn         Full-time
# 3               San Antonio, TX   via Diversity.com         Full-time
# 4                Washington, DC  via Clearance Jobs         Full-time
#
#    job_work_from_home       search_location     job_posted_date  \
# ...
