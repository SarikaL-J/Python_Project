# %%
import pandas as pd  #import all libraries
import matplotlib.pyplot as plt 
import ast
df = pd.read_csv("/Users/jastisarika/Downloads/data_jobs.csv")  #load the csv file
#Data Cleanup
df["job_posted_date"] = pd.to_datetime(df.job_posted_date)
df["job_skills"] = df["job_skills"].apply(lambda x:ast.literal_eval(x) if pd.notna(x) else x)
df.head(5)
# Out:
#         job_title_short                                          job_title  \
# 0  Senior Data Engineer  Senior Clinical Data Engineer / Principal Clin...
# 1          Data Analyst                                       Data Analyst
# 2         Data Engineer  Data Engineer/Scientist/Analyst, Mid or Senior...
# 3         Data Engineer  LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4         Data Engineer                             Data Engineer- Sr Jobs
#
#                    job_location             job_via job_schedule_type  \
# 0                 Watertown, CT     via Work Nearby         Full-time
# 1  Guadalajara, Jalisco, Mexico    via BeBee México         Full-time
# 2               Berlin, Germany        via LinkedIn         Full-time
# 3               San Antonio, TX   via Diversity.com         Full-time
# 4                Washington, DC  via Clearance Jobs         Full-time
#
#    job_work_from_home       search_location     job_posted_date  \
# ...

# %% [markdown]
# Investigate Trending skills - that means w ehave to find the skills that are posted over a time period.. here we are investigationg/aggregating these top skills that are posted over the months of the year like jan, feb, march

# %%
df_da = df[df["job_title_short"]=="Data Analyst"].copy()
df_da.head(3)
# Out:
#    job_title_short                                    job_title  \
# 1     Data Analyst                                 Data Analyst
# 12    Data Analyst  Stagiaire Data Analyst (H/F) - Lyon (69006)
# 18    Data Analyst                                 Data Analyst
#
#                     job_location                job_via  \
# 1   Guadalajara, Jalisco, Mexico       via BeBee México
# 12                  Lyon, France           via Jobijoba
# 18                Warsaw, Poland  via Praca Trabajo.org
#
#            job_schedule_type  job_work_from_home search_location  \
# 1                  Full-time               False          Mexico
# 12  Full-time and Internship               False          France
# 18                 Full-time               False          Poland
#
#        job_posted_date  job_no_degree_mention  job_health_insurance  \
# 1  2023-01-14 13:18:07                  False                 False
# 12 2023-12-22 13:24:41                  False                 False
# ...

# %%
df_da["job_posted_month_no"] = df["job_posted_date"].dt.month
df_da.head()
# Out:
#    job_title_short                                          job_title  \
# 1     Data Analyst                                       Data Analyst
# 12    Data Analyst        Stagiaire Data Analyst (H/F) - Lyon (69006)
# 18    Data Analyst                                       Data Analyst
# 31    Data Analyst                           Stage - Data Analyst F/H
# 34    Data Analyst  Data Analyst als Marketing Manager Automation ...
#
#                     job_location                          job_via  \
# 1   Guadalajara, Jalisco, Mexico                 via BeBee México
# 12                  Lyon, France                     via Jobijoba
# 18                Warsaw, Poland            via Praca Trabajo.org
# 31                 Paris, France                     via LinkedIn
# 34             Erlangen, Germany  via Central Illinois Proud Jobs
#
#            job_schedule_type  job_work_from_home search_location  \
# 1                  Full-time               False          Mexico
# ...

# %%
 # now we have to explode out the job skillls 
df_da_exploded = df_da.explode("job_skills")
df_da_exploded.head()
# Out:
#   job_title_short     job_title                  job_location  \
# 1    Data Analyst  Data Analyst  Guadalajara, Jalisco, Mexico
# 1    Data Analyst  Data Analyst  Guadalajara, Jalisco, Mexico
# 1    Data Analyst  Data Analyst  Guadalajara, Jalisco, Mexico
# 1    Data Analyst  Data Analyst  Guadalajara, Jalisco, Mexico
# 1    Data Analyst  Data Analyst  Guadalajara, Jalisco, Mexico
#
#             job_via job_schedule_type  job_work_from_home search_location  \
# 1  via BeBee México         Full-time               False          Mexico
# 1  via BeBee México         Full-time               False          Mexico
# 1  via BeBee México         Full-time               False          Mexico
# 1  via BeBee México         Full-time               False          Mexico
# 1  via BeBee México         Full-time               False          Mexico
#
#       job_posted_date  job_no_degree_mention  job_health_insurance  \
# 1 2023-01-14 13:18:07                  False                 False
# ...

# %%
# df_da_exploded.pivot_table(index = "job_posted_month_no", columns = "job_skills" , aggfunc="size") 
 #after this i notice that there are nan values, but we cant plot nan values ..
# so turn them in to a 0 value

# %%
df_da_pivot = df_da_exploded.pivot_table(index = "job_posted_month_no", columns = "job_skills" , aggfunc="size",fill_value=0) 
df_da_pivot
# Out:
# job_skills           airflow  airtable  alteryx  angular  angular.js  ansible  \
# job_posted_month_no
# 1                        197        17      551       63           2       20
# 2                        169         2      448       49           0       14
# 3                        181         4      442       34           0       23
# 4                        155         4      413       22           0       11
# 5                        128         8      310       30           0       19
# 6                        164        14      393       29           0       14
# 7                        207         4      366       15           0        8
# 8                        197         3      413       21           0       12
# 9                        118         4      317       21           0       14
# 10                       173        11      350       40           0       19
# 11                       169         7      293       24           0       19
# ...

# %%
#there are lot of skills , 
# we need to filter dwon  the skills depnedning on the highest count of skills,
#  we will know by summing up or a total value athe end of each column pf the skill . for this we need a add a row at the end of each column by summing up 
df_da_pivot.loc['total'] = df_da_pivot.sum()

# %%
df_da_pivot
# Out:
# job_skills           airflow  airtable  alteryx  angular  angular.js  ansible  \
# job_posted_month_no
# 1                        197        17      551       63           2       20
# 2                        169         2      448       49           0       14
# 3                        181         4      442       34           0       23
# 4                        155         4      413       22           0       11
# 5                        128         8      310       30           0       19
# 6                        164        14      393       29           0       14
# 7                        207         4      366       15           0        8
# 8                        197         3      413       21           0       12
# 9                        118         4      317       21           0       14
# 10                       173        11      350       40           0       19
# 11                       169         7      293       24           0       19
# ...

# %%
# # #now sort these columns by total 
# # df_da_pivot.loc['total'].sort_values(ascending = False ).index  #aftert this , we need column titles as a index...
# now pass the above one to a df_pivot to sort the columns by this
df_da_pivot[df_da_pivot.loc['total'].sort_values(ascending = False ).index]  
df_da_pivot = df_da_pivot[df_da_pivot.loc['total'].sort_values(ascending = False ).index]
df_da_pivot
# Out:
# job_skills             sql  excel  python  tableau  power bi      r    sas  \
# job_posted_month_no
# 1                    11336   8170    6606     5596      4285   3607   3830
# 2                     7947   5772    4751     3936      3307   2576   2634
# 3                     7868   5675    4741     4051      3176   2650   2554
# 4                     7553   5496    4557     3776      3106   2399   2598
# 5                     6617   4773    4070     3245      2695   2093   1940
# 6                     7584   5724    4707     3812      3275   2442   2174
# 7                     7687   5513    4831     3928      3350   2444   2118
# 8                     8823   6482    5576     4533      3859   2975   2560
# 9                     6829   4886    4229     3446      3118   2146   1880
# 10                    7474   5217    4693     3709      3340   2380   2114
# 11                    6652   4776    4233     3284      3012   2159   1738
# ...

# %%
df_da_pivot = df_da_pivot.drop('total')
df_da_pivot
# Out:
# job_skills             sql  excel  python  tableau  power bi     r   sas  \
# job_posted_month_no
# 1                    11336   8170    6606     5596      4285  3607  3830
# 2                     7947   5772    4751     3936      3307  2576  2634
# 3                     7868   5675    4741     4051      3176  2650  2554
# 4                     7553   5496    4557     3776      3106  2399  2598
# 5                     6617   4773    4070     3245      2695  2093  1940
# 6                     7584   5724    4707     3812      3275  2442  2174
# 7                     7687   5513    4831     3928      3350  2444  2118
# 8                     8823   6482    5576     4533      3859  2975  2560
# 9                     6829   4886    4229     3446      3118  2146  1880
# 10                    7474   5217    4693     3709      3340  2380  2114
# 11                    6652   4776    4233     3284      3012  2159  1738
# 12                    6058   4376    4196     3139      2857  2125  1858
# ...

# %%
df_da_pivot.iloc[:,0:5]
# Out:
# job_skills             sql  excel  python  tableau  power bi
# job_posted_month_no
# 1                    11336   8170    6606     5596      4285
# 2                     7947   5772    4751     3936      3307
# 3                     7868   5675    4741     4051      3176
# 4                     7553   5496    4557     3776      3106
# 5                     6617   4773    4070     3245      2695
# 6                     7584   5724    4707     3812      3275
# 7                     7687   5513    4831     3928      3350
# 8                     8823   6482    5576     4533      3859
# 9                     6829   4886    4229     3446      3118
# 10                    7474   5217    4693     3709      3340
# 11                    6652   4776    4233     3284      3012
# 12                    6058   4376    4196     3139      2857

# %%
df_da_pivot.iloc[:,0:5].plot(kind='line')
plt.ylabel('count')
plt.xlabel('')
plt.legend()
plt.show()

# %%
df_da_pivot.head()
# Out:
# job_skills             sql  excel  python  tableau  power bi     r   sas  \
# job_posted_month_no
# 1                    11336   8170    6606     5596      4285  3607  3830
# 2                     7947   5772    4751     3936      3307  2576  2634
# 3                     7868   5675    4741     4051      3176  2650  2554
# 4                     7553   5496    4557     3776      3106  2399  2598
# 5                     6617   4773    4070     3245      2695  2093  1940
#
# job_skills           powerpoint  word   sap  ...  angular.js  xamarin  gtx  \
# job_posted_month_no                          ...
# 1                          1880  1778  1251  ...           2        0    0
# 2                          1291  1235   954  ...           0        0    0
# 3                          1266  1203   892  ...           0        1    0
# 4                          1190  1177   947  ...           0        0    0
# 5                           979   957   851  ...           0        0    0
#
# ...

# %%
df_da_pivot = df_da_pivot.reset_index()
df_da_pivot["job_posted_month"] = df_da_pivot["job_posted_month_no"].apply(lambda x: pd.to_datetime(x,format='%m').strftime('%B'))

# %%
df_da_pivot = df_da_pivot.set_index("job_posted_month")
df_da_pivot = df_da_pivot.drop(columns = 'job_posted_month_no')

# %%
df_da_pivot
# Out:
# job_skills          sql  excel  python  tableau  power bi     r   sas  \
# job_posted_month
# January           11336   8170    6606     5596      4285  3607  3830
# February           7947   5772    4751     3936      3307  2576  2634
# March              7868   5675    4741     4051      3176  2650  2554
# April              7553   5496    4557     3776      3106  2399  2598
# May                6617   4773    4070     3245      2695  2093  1940
# June               7584   5724    4707     3812      3275  2442  2174
# July               7687   5513    4831     3928      3350  2444  2118
# August             8823   6482    5576     4533      3859  2975  2560
# September          6829   4886    4229     3446      3118  2146  1880
# October            7474   5217    4693     3709      3340  2380  2114
# November           6652   4776    4233     3284      3012  2159  1738
# December           6058   4376    4196     3139      2857  2125  1858
#
# ...

# %%
df_da_pivot.iloc[:,:5].plot(kind='line')
# Out:
# <Axes: xlabel='job_posted_month'>
