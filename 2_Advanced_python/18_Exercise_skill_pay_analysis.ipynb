# %%
import pandas as pd  #import all libraries
import matplotlib.pyplot as plt 
import ast
df = pd.read_csv("/Users/jastisarika/Downloads/data_jobs.csv")  #load the csv file
#Data Cleanup
df["job_posted_date"] = pd.to_datetime(df.job_posted_date)
df["job_skills"] = df["job_skills"].apply(lambda x:ast.literal_eval(x) if pd.notna(x) else x)
df.head(5)
# Out:
#         job_title_short                                          job_title  \
# 0  Senior Data Engineer  Senior Clinical Data Engineer / Principal Clin...
# 1          Data Analyst                                       Data Analyst
# 2         Data Engineer  Data Engineer/Scientist/Analyst, Mid or Senior...
# 3         Data Engineer  LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4         Data Engineer                             Data Engineer- Sr Jobs
#
#                    job_location             job_via job_schedule_type  \
# 0                 Watertown, CT     via Work Nearby         Full-time
# 1  Guadalajara, Jalisco, Mexico    via BeBee México         Full-time
# 2               Berlin, Germany        via LinkedIn         Full-time
# 3               San Antonio, TX   via Diversity.com         Full-time
# 4                Washington, DC  via Clearance Jobs         Full-time
#
#    job_work_from_home       search_location     job_posted_date  \
# 0               False  Texas, United States 2023-06-16 13:44:15
# 1               False                Mexico 2023-01-14 13:18:07
# 2               False               Germany 2023-10-10 13:14:55
# 3               False  Texas, United States 2023-07-04 13:01:41
# 4               False                 Sudan 2023-08-07 14:29:36
#
#    job_no_degree_mention  job_health_insurance    job_country salary_rate  \
# 0                  False                 False  United States         NaN
# 1                  False                 False         Mexico         NaN
# 2                  False                 False        Germany         NaN
# 3                   True                 False  United States         NaN
# 4                  False                 False          Sudan         NaN
#
#    salary_year_avg  salary_hour_avg                  company_name  \
# 0              NaN              NaN          Boehringer Ingelheim
# 1              NaN              NaN    Hewlett Packard Enterprise
# 2              NaN              NaN      ALPHA Augmented Services
# 3              NaN              NaN  Southwest Research Institute
# 4              NaN              NaN               Kristina Daniel
#
#                                           job_skills  \
# 0                                                NaN
# 1         [r, python, sql, nosql, power bi, tableau]
# 2  [python, sql, c#, azure, airflow, dax, docker,...
# 3  [python, c++, java, matlab, aws, tensorflow, k...
# 4  [bash, python, oracle, aws, ansible, puppet, j...
#
#                                      job_type_skills
# 0                                                NaN
# 1  {'analyst_tools': ['power bi', 'tableau'], 'pr...
# 2  {'analyst_tools': ['dax'], 'cloud': ['azure'],...
# 3  {'cloud': ['aws'], 'libraries': ['tensorflow',...
# 4  {'cloud': ['oracle', 'aws'], 'other': ['ansibl...

# %%
#get the data analyst jobs from usa 
df_da_usa = df[(df["job_title_short"]=='Data Analyst') & (df["job_country"]=='United States')].copy()

#drop nan values from th column for plotting 
df_da_usa = df_da_usa.dropna(subset=["salary_year_avg"])
df_da_usa = df_da_usa.explode('job_skills')

# %%
#  for data analyst usa ... what is the pay for their associate skills . specificially i wan to analyse from 2 perspectives 
# 1.i wan to see in general what are the top 10 paying skills 
# 2.and relate to that which skillls have more demand or highest count and thier associate salaries

# %%
df_da_usa[["salary_year_avg","job_skills"]]
# Out:
#         salary_year_avg job_skills
# 109             89000.0     python
# 109             89000.0          r
# 109             89000.0    alteryx
# 109             89000.0    tableau
# 180             90250.0      excel
# ...                 ...        ...
# 784882          87500.0        sql
# 784882          87500.0        vba
# 784882          87500.0    tableau
# 784882          87500.0      excel
# 784882          87500.0    alteryx
#
# [17440 rows x 2 columns]

# %%
df_da_usa_group = df_da_usa.groupby('job_skills')["salary_year_avg"].agg(['count','median']) 
 # count of the cskills and median of the sallaries\

# %% [markdown]
# we need 2 new dataframes
# 1.top 10 highest salries
# 2.top 10 skills  with highest count wiht associate salaris

# %%
df_da_top_pay = df_da_usa_group.sort_values(by='median', ascending = False).head(10)  #we get top 10 skills based on median salary 
df_da_top_pay
# Out:
#               count    median
# job_skills
# dplyr             2  196250.0
# bitbucket         3  189000.0
# gitlab            3  186000.0
# solidity          1  179000.0
# hugging face      1  175000.0
# couchbase         1  160515.0
# ansible           1  159640.0
# mxnet             2  149000.0
# cassandra         6  148250.0
# vmware            1  147500.0

# %%
df_da_skils =df_da_usa_group.sort_values(by="count",ascending=False).head(10).sort_values(by='median', ascending = False) #here forst we have to sort by count and then we have to sort by median   #top 10 skills with higest count and their associate salary 
df_da_skils
# Out:
#             count    median
# job_skills
# python       1431  97500.00
# tableau      1364  92875.00
# r             893  92500.00
# sql server    286  92500.00
# sql          2508  91000.00
# sas           926  90000.00
# power bi      838  90000.00
# powerpoint    462  85000.00
# excel        1808  84392.00
# word          461  81194.75

# %%
fig, ax = plt.subplots(2,1)
df_da_top_pay.plot(kind='barh',y='median',ax = ax[0],legend = False)
ax[0].invert_yaxis()   #sort in correct order 
ax[0].set_title('Top 10 Highest paid skills for Data Analsyts in USA')
ax[0].set_xlabel('')
ax[0].set_ylabel('')
ax[0].xaxis.set_major_formatter(plt.FuncFormatter(lambda x, pos: f'${int(x/1000)}k'))

df_da_skils.plot(kind='barh',y='median',ax = ax[1], legend = False)
ax[1].invert_yaxis()
ax[1].set_xlim(ax[0].get_xlim())     #set limit of ax[1] whatever is with ax[0]
ax[1].set_title('Top 10 Most-In Demand skills for Data Analsyts in USA')
ax[1].set_xlabel('Median Salary ($USD)')
ax[1].set_ylabel('')
ax[1].xaxis.set_major_formatter(plt.FuncFormatter(lambda x, pos: f'${int(x/1000)}k'))

fig.tight_layout()
fig.show()
# Out:
# /var/folders/hl/02cmh7nn2wnf3q30t5d75cdr0000gn/T/ipykernel_93675/681513805.py:18: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
