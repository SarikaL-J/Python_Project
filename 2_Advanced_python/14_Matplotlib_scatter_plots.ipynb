# %%
import pandas as pd  #import all libraries
import matplotlib.pyplot as plt 
import ast
df = pd.read_csv("/Users/jastisarika/Downloads/data_jobs.csv")  #load the csv file
#Data Cleanup
df["job_posted_date"] = pd.to_datetime(df.job_posted_date)
df["job_skills"] = df["job_skills"].apply(lambda x:ast.literal_eval(x) if pd.notna(x) else x)
df.head(5)
# Out:
#         job_title_short                                          job_title  \
# 0  Senior Data Engineer  Senior Clinical Data Engineer / Principal Clin...
# 1          Data Analyst                                       Data Analyst
# 2         Data Engineer  Data Engineer/Scientist/Analyst, Mid or Senior...
# 3         Data Engineer  LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4         Data Engineer                             Data Engineer- Sr Jobs
#
#                    job_location             job_via job_schedule_type  \
# 0                 Watertown, CT     via Work Nearby         Full-time
# 1  Guadalajara, Jalisco, Mexico    via BeBee México         Full-time
# 2               Berlin, Germany        via LinkedIn         Full-time
# 3               San Antonio, TX   via Diversity.com         Full-time
# 4                Washington, DC  via Clearance Jobs         Full-time
#
#    job_work_from_home       search_location     job_posted_date  \
# ...

# %%
df = df[df["job_title_short"]== 'Data Analyst']
df
df_exploded = df.explode('job_skills')
df_exploded
# Out:
#        job_title_short                           job_title  \
# 1         Data Analyst                        Data Analyst
# 1         Data Analyst                        Data Analyst
# 1         Data Analyst                        Data Analyst
# 1         Data Analyst                        Data Analyst
# 1         Data Analyst                        Data Analyst
# ...                ...                                 ...
# 785717    Data Analyst  Data & Analytics Architect (w/m/x)
# 785737    Data Analyst                    CRM Data Analyst
# 785737    Data Analyst                    CRM Data Analyst
# 785737    Data Analyst                    CRM Data Analyst
# 785737    Data Analyst                    CRM Data Analyst
#
#                         job_location                    job_via  \
# 1       Guadalajara, Jalisco, Mexico           via BeBee México
# 1       Guadalajara, Jalisco, Mexico           via BeBee México
# ...

# %%
#now we need to groupby job skills and get count of them and agg median salary  ... 
# we have to get the size of jobskills and we need to get the median salary..
#  tis is called multiple agg\\

skills_stats = df_exploded.groupby("job_skills").agg(
    skill_count = ('job_skills' ,'count'),
    Median_salary =("salary_year_avg",'median')
)
skills_stats
# Out:
#             skill_count  Median_salary
# job_skills
# airflow            2002       111175.0
# airtable             88        90000.0
# alteryx            4570       105000.0
# angular             376       109101.0
# angular.js            2            NaN
# ...                 ...            ...
# wrike                39        75000.0
# wsl                  16            NaN
# xamarin               2            NaN
# yarn                 76        99150.0
# zoom                465        81167.0
#
# [235 rows x 2 columns]

# %%
skill_stats = skills_stats.sort_values(by = 'skill_count', ascending= False).head(10)
skill_stats
# Out:
#             skill_count  Median_salary
# job_skills
# sql               92428        92500.0
# excel             66860        84479.0
# python            57190        98500.0
# tableau           46455        95000.0
# power bi          39380        90000.0
# r                 29996        92527.5
# sas               27998        90000.0
# powerpoint        13822        85000.0
# word              13562        80000.0
# sap               11280        90000.0

# %%
skill_stats.plot(kind ='scatter',x='skill_count',y ='Median_salary')
plt.title("salary vs count of job postings for top 10 skills")
plt.xlabel("count of job postings")
plt.ylabel("Median yearly salary ($USD)")
plt.tight_layout
for i,txt in enumerate(skill_stats.index):  #here i, txt are the index and column of the df we are using 
    plt.text(skill_stats['skill_count'].iloc[i], skill_stats["Median_salary"].iloc[i],txt)   # we have use plt.text(x label, y label , txt )
plt.show()

# %%
# from this plot, we can say that python, tableu and sql are not only paid well but are also in demand
