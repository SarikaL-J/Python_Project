# %%
import pandas as pd  #import all libraries
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("/Users/jastisarika/Downloads/data_jobs.csv")  #load the csv file

# %%
#data cleaning  - change the date data type
df["job_posted_date"] = pd.to_datetime(df.job_posted_date)

# %%
df
# Out:
#              job_title_short  \
# 0       Senior Data Engineer
# 1               Data Analyst
# 2              Data Engineer
# 3              Data Engineer
# 4              Data Engineer
# ...                      ...
# 785736     Software Engineer
# 785737          Data Analyst
# 785738      Business Analyst
# 785739         Data Engineer
# 785740     Software Engineer
#
#                                                 job_title  \
# 0       Senior Clinical Data Engineer / Principal Clin...
# 1                                            Data Analyst
# 2       Data Engineer/Scientist/Analyst, Mid or Senior...
# 3       LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4                                  Data Engineer- Sr Jobs
# ...                                                   ...
# 785736                                    DevOps Engineer
# 785737                                   CRM Data Analyst
# 785738                     Commercial Analyst - Start Now
# ...

# %%
#couunt of job titles
df.pivot_table(values ="salary_year_avg", index='job_country',columns="job_title_short",aggfunc='median')
# Out:
# job_title_short  Business Analyst  Cloud Engineer  Data Analyst  \
# job_country
# Albania                       NaN             NaN      49950.00
# Algeria                       NaN             NaN      44100.00
# Argentina                 71100.0        197500.0      92771.75
# Armenia                       NaN             NaN     100500.00
# Australia                 70000.0        110000.0     109500.00
# ...                           ...             ...           ...
# Uruguay                       NaN             NaN     100500.00
# Uzbekistan                    NaN             NaN           NaN
# Vietnam                   79200.0             NaN      75550.00
# Zambia                        NaN             NaN           NaN
# Zimbabwe                      NaN             NaN      63000.00
#
# job_title_short  Data Engineer  Data Scientist  Machine Learning Engineer  \
# job_country
# Albania                    NaN        69981.25                        NaN
# ...

# %%
#we want to agg and find top 6 countries along with plotting median salries for different job titles
top_countries = df['job_country'].value_counts()
top_countries
# Out:
# job_country
# United States     206292
# India              51088
# United Kingdom     40375
# France             39922
# Germany            27694
#                    ...
# Guinea                 4
# Mauritania             3
# Lesotho                3
# Bhutan                 3
# Maldives               2
# Name: count, Length: 160, dtype: int64

# %%
top_countries=top_countries.head(6).index  #WE Need index for this list as u can see job countries are in index so get only index

# %%
top_countries
# Out:
# Index(['United States', 'India', 'United Kingdom', 'France', 'Germany',
#        'Spain'],
#       dtype='object', name='job_country')

# %%
df_job_country_salary = df.pivot_table(values ="salary_year_avg", 
index='job_country',
columns="job_title_short",
aggfunc='median')                   #here now we assigned pivot table to a varibale and now we have tofilter this table only with the top countries

# %%
df_job_country_salary = df_job_country_salary.loc[top_countries]

# %%
df_job_country_salary
# Out:
# job_title_short  Business Analyst  Cloud Engineer  Data Analyst  \
# job_country
# United States             90000.0        116100.0       90000.0
# India                     64800.0             NaN      100500.0
# United Kingdom            56700.0             NaN       87750.0
# France                    89100.0        105968.0       69175.0
# Germany                   89100.0         89100.0      103750.0
# Spain                     86400.0         89100.0       91977.0
#
# job_title_short  Data Engineer  Data Scientist  Machine Learning Engineer  \
# job_country
# United States         125000.0        130000.0                   150000.0
# India                 147500.0        114008.0                    79200.0
# United Kingdom        110000.0        105300.0                   149653.0
# France                 98301.5         88128.0                    80850.0
# Germany               147500.0        131560.0                    89100.0
# ...

# %%
df_job_country_salary.plot(kind='bar')
# Out:
# <Axes: xlabel='job_country'>

# %%
#now i want to see only specifi job titles
job_titles = ["Data Analyst",'Data Engineer','Data Scientist']    #since these are the colimns we nedd to use iloc or loc... we just need to sccess these clumns..

df_job_country_salary = df_job_country_salary[job_titles]

# %%
df_job_country_salary.plot(kind = 'bar')
#clean this by giving x label and y label 
plt.ylabel("Median Salary ($USD)")
plt.xlabel('')
plt.title("Median salary by country & Title")
plt.xticks(rotation = 45, ha ='right')
plt.show()
