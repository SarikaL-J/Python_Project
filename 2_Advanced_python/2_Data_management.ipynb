# %%
import pandas as pd  #import all libraries
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("/Users/jastisarika/Downloads/data_jobs.csv")  #load the csv file

# %%
df
# Out:
#              job_title_short  \
# 0       Senior Data Engineer
# 1               Data Analyst
# 2              Data Engineer
# 3              Data Engineer
# 4              Data Engineer
# ...                      ...
# 785736     Software Engineer
# 785737          Data Analyst
# 785738      Business Analyst
# 785739         Data Engineer
# 785740     Software Engineer
#
#                                                 job_title  \
# 0       Senior Clinical Data Engineer / Principal Clin...
# 1                                            Data Analyst
# 2       Data Engineer/Scientist/Analyst, Mid or Senior...
# 3       LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4                                  Data Engineer- Sr Jobs
# ...                                                   ...
# 785736                                    DevOps Engineer
# 785737                                   CRM Data Analyst
# 785738                     Commercial Analyst - Start Now
# ...

# %%
#data cleaning  - change the date data type
df["job_posted_date"] = pd.to_datetime(df.job_posted_date)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 785741 entries, 0 to 785740
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   job_title_short        785741 non-null  object
#  1   job_title              785740 non-null  object
#  2   job_location           784696 non-null  object
#  3   job_via                785733 non-null  object
#  4   job_schedule_type      773074 non-null  object
#  5   job_work_from_home     785741 non-null  bool
#  6   search_location        785741 non-null  object
#  7   job_posted_date        785741 non-null  datetime64[ns]
#  8   job_no_degree_mention  785741 non-null  bool
#  9   job_health_insurance   785741 non-null  bool
#  10  job_country            785692 non-null  object
#  11  salary_rate            33067 non-null   object
#  12  salary_year_avg        22003 non-null   float64
#  13  salary_hour_avg        10662 non-null   float64
# ...

# %% [markdown]
# #Sample

# %%
# df.head() and df.tail() both return continous values and does not represent the whole df.. if we want to represent the whole date , 
# we should create a sample data frame . lest see how to create a sample dataframe -

# %%
#it returns the random sample of data - see the index - we have randomly selected
df.sample(10) #everytime we run this query, we get 10 different samples.. so we have to mention randomstate
# Out:
#               job_title_short  \
# 688313       Business Analyst
# 394568       Business Analyst
# 47224   Senior Data Scientist
# 529771          Data Engineer
# 69564          Data Scientist
# 373344          Data Engineer
# 354998           Data Analyst
# 663713           Data Analyst
# 477607          Data Engineer
# 133146           Data Analyst
#
#                                                 job_title  \
# 688313                            WFM - Workforce Analyst
# 394568                                   Business Analyst
# 47224   Senior Data Scientist - Omnichannel Supply Cha...
# 529771                                 Data Engineer Jobs
# 69564                                 Information Analyst
# 373344  Computer Scientist - Data Engineer / Data Plat...
# 354998      Internship:  Production Planning Data Analyst
# 663713                                  Analytics Officer
# 477607  Data Architect/AI Architect/Big Data Architect...
# ...

# %%
df.sample(10, random_state=42)
# Out:
#               job_title_short  \
# 502901   Senior Data Engineer
# 406337  Senior Data Scientist
# 659951          Data Engineer
# 541593           Data Analyst
# 425158   Senior Data Engineer
# 183426           Data Analyst
# 287790           Data Analyst
# 541983           Data Analyst
# 416896         Data Scientist
# 780907          Data Engineer
#
#                                                 job_title  \
# 502901                               Senior Data Engineer
# 406337                          Senior Analytics Engineer
# 659951                                      Data Engineer
# 541593                                       Data Analyst
# 425158  Senior Data Engineer. Job in Amsterdam NBC4i Jobs
# 183426                                       Data Analyst
# 287790                                       Data Analyst
# 541983                   Data Analyst, Cloud Systems Jobs
# 416896             Alternant Actuariat & Data Science H/F
# ...

# %% [markdown]
# #copy -make a copy this objects indices and data
# a new object will be created with a copy of calling object's data and indices. Any modifications to the data or indices  of the copy will not be reflected int he original data . lets understand by using example

# %%
df_altered = df

# %%
df_altered.loc[0:5,'salary_year_avg']
# Out:
# 0   NaN
# 1   NaN
# 2   NaN
# 3   NaN
# 4   NaN
# 5   NaN
# Name: salary_year_avg, dtype: float64

# %%
median_salary_year = df_altered['salary_year_avg'].median()
median_salary_year
# Out:
# 115000.0

# %%
df['salary_year_avg'] = df['salary_year_avg'].fillna(median_salary_year)

# %%
df_altered.loc[0:5,'salary_year_avg']
# Out:
# 0    115000.0
# 1    115000.0
# 2    115000.0
# 3    115000.0
# 4    115000.0
# 5    115000.0
# Name: salary_year_avg, dtype: float64

# %%
df  # see here df is also altered or modified as df_altered..because id(df) = id(df_altered) becos, df=df_altered
#  that is why we have to create a copy of datafram so that original and copy will be diff
# Out:
#              job_title_short  \
# 0       Senior Data Engineer
# 1               Data Analyst
# 2              Data Engineer
# 3              Data Engineer
# 4              Data Engineer
# ...                      ...
# 785736     Software Engineer
# 785737          Data Analyst
# 785738      Business Analyst
# 785739         Data Engineer
# 785740     Software Engineer
#
#                                                 job_title  \
# 0       Senior Clinical Data Engineer / Principal Clin...
# 1                                            Data Analyst
# 2       Data Engineer/Scientist/Analyst, Mid or Senior...
# 3       LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4                                  Data Engineer- Sr Jobs
# ...                                                   ...
# 785736                                    DevOps Engineer
# 785737                                   CRM Data Analyst
# 785738                     Commercial Analyst - Start Now
# ...

# %%
id(df)
# Out:
# 5628155936

# %%
id(df_altered)  #both are same
# Out:
# 5628155936

# %%
df_altered = df.copy()

# %%
id(df_altered)
# Out:
# 5074850576

# %%
id(df)
# Out:
# 5628155936
