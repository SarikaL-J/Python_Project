# %%
print("hey!")
# Out:
# hey!

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
from datasets import load_dataset

# %%
df = pd.read_csv("/Users/jastisarika/Downloads/data_jobs.csv")

# %%
df.head()
# Out:
#         job_title_short                                          job_title  \
# 0  Senior Data Engineer  Senior Clinical Data Engineer / Principal Clin...
# 1          Data Analyst                                       Data Analyst
# 2         Data Engineer  Data Engineer/Scientist/Analyst, Mid or Senior...
# 3         Data Engineer  LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4         Data Engineer                             Data Engineer- Sr Jobs
#
#                    job_location             job_via job_schedule_type  \
# 0                 Watertown, CT     via Work Nearby         Full-time
# 1  Guadalajara, Jalisco, Mexico    via BeBee México         Full-time
# 2               Berlin, Germany        via LinkedIn         Full-time
# 3               San Antonio, TX   via Diversity.com         Full-time
# 4                Washington, DC  via Clearance Jobs         Full-time
#
#    job_work_from_home       search_location      job_posted_date  \
# ...

# %% [markdown]
# Goal:
# #I want to analyse Top Paying Jobs and Skills
# #I will write Python code to explore this large dataset specifi to me

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 785741 entries, 0 to 785740
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   job_title_short        785741 non-null  object
#  1   job_title              785740 non-null  object
#  2   job_location           784696 non-null  object
#  3   job_via                785733 non-null  object
#  4   job_schedule_type      773074 non-null  object
#  5   job_work_from_home     785741 non-null  bool
#  6   search_location        785741 non-null  object
#  7   job_posted_date        785741 non-null  object
#  8   job_no_degree_mention  785741 non-null  bool
#  9   job_health_insurance   785741 non-null  bool
#  10  job_country            785692 non-null  object
#  11  salary_rate            33067 non-null   object
#  12  salary_year_avg        22003 non-null   float64
#  13  salary_hour_avg        10662 non-null   float64
# ...

# %%
df['job_posted_date']= pd.to_datetime(df.job_posted_date)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 785741 entries, 0 to 785740
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   job_title_short        785741 non-null  object
#  1   job_title              785740 non-null  object
#  2   job_location           784696 non-null  object
#  3   job_via                785733 non-null  object
#  4   job_schedule_type      773074 non-null  object
#  5   job_work_from_home     785741 non-null  bool
#  6   search_location        785741 non-null  object
#  7   job_posted_date        785741 non-null  datetime64[ns]
#  8   job_no_degree_mention  785741 non-null  bool
#  9   job_health_insurance   785741 non-null  bool
#  10  job_country            785692 non-null  object
#  11  salary_rate            33067 non-null   object
#  12  salary_year_avg        22003 non-null   float64
#  13  salary_hour_avg        10662 non-null   float64
# ...

# %%
df.iloc[0]  #accessing data by using index
# Out:
# job_title_short                                       Senior Data Engineer
# job_title                Senior Clinical Data Engineer / Principal Clin...
# job_location                                                 Watertown, CT
# job_via                                                    via Work Nearby
# job_schedule_type                                                Full-time
# job_work_from_home                                                   False
# search_location                                       Texas, United States
# job_posted_date                                        2023-06-16 13:44:15
# job_no_degree_mention                                                False
# job_health_insurance                                                 False
# job_country                                                  United States
# salary_rate                                                            NaN
# ...

# %%
df.iloc[100:104] #we can access rows by using row indices.. but if we ant to access column with index number,, that would be hard to count the index everytime..
# Out:
#     job_title_short                                job_title  \
# 100  Data Scientist  Data Scientist, Risk Data Mining - USDS
# 101    Data Analyst                             Data Analyst
# 102  Data Scientist                           Data Scientist
# 103   Data Engineer               Data Engineering Team Lead
#
#                                        job_location              job_via  \
# 100                               Mountain View, CA         via LinkedIn
# 101                                       Singapore  via BeBee Singapore
# 102  Rome, Metropolitan City of Rome Capital, Italy            via BeBee
# 103                                        Anywhere           via Indeed
#
#     job_schedule_type  job_work_from_home            search_location  \
# 100         Full-time               False  California, United States
# 101         Full-time               False                  Singapore
# 102         Full-time               False                      Italy
# ...

# %%
df.loc[0:6, ['salary_hour_avg','salary_hour_avg']]  # we can access a list of columns  by loc method
# Out:
#    salary_hour_avg  salary_hour_avg
# 0              NaN              NaN
# 1              NaN              NaN
# 2              NaN              NaN
# 3              NaN              NaN
# 4              NaN              NaN
# 5              NaN              NaN
# 6              NaN              NaN

# %%
df.loc[:,'salary_rate':'salary_hour_avg'].dropna(subset = 'salary_rate')  #here we are filtering the data ie droppping the rows where salary_rate has nan values
# Out:
#        salary_rate  salary_year_avg  salary_hour_avg
# 28            year         109500.0              NaN
# 43            hour              NaN             97.5
# 51            hour              NaN             72.5
# 77            year         140000.0              NaN
# 92            year         120000.0              NaN
# ...            ...              ...              ...
# 785624        year         139216.0              NaN
# 785641        year         150000.0              NaN
# 785648        year         221875.0              NaN
# 785682        year         157500.0              NaN
# 785692        year         157500.0              NaN
#
# [33067 rows x 3 columns]

# %%
# lets calculate median values and fill Nan  values with median 
df['salary_year_avg'].median()  
#lets assign a variable and store this value in the varibale
Median_salary_year = df['salary_year_avg'].median()

# %%
# lets calculate median values and fill Nan  values with median 
df['salary_hour_avg'].median()  
#lets assign a variable and store this value in the varibale
Median_Salary_Hour = df['salary_hour_avg'].median()

# %%
df_filled = df

# %%
df_filled["salary_year_avg"].fillna(Median_salary_year)
df_filled['salary_hour_avg'].fillna(Median_Salary_Hour)
# Out:
# 0         45.98
# 1         45.98
# 2         45.98
# 3         45.98
# 4         45.98
#           ...
# 785736    45.98
# 785737    45.98
# 785738    45.98
# 785739    45.98
# 785740    45.98
# Name: salary_hour_avg, Length: 785741, dtype: float64

# %%
df_filled["salary_hour_avg"]= df_filled['salary_hour_avg'].fillna(Median_Salary_Hour)

# %%
df_filled
# Out:
#              job_title_short  \
# 0       Senior Data Engineer
# 1               Data Analyst
# 2              Data Engineer
# 3              Data Engineer
# 4              Data Engineer
# ...                      ...
# 785736     Software Engineer
# 785737          Data Analyst
# 785738      Business Analyst
# 785739         Data Engineer
# 785740     Software Engineer
#
#                                                 job_title  \
# 0       Senior Clinical Data Engineer / Principal Clin...
# 1                                            Data Analyst
# 2       Data Engineer/Scientist/Analyst, Mid or Senior...
# 3       LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4                                  Data Engineer- Sr Jobs
# ...                                                   ...
# 785736                                    DevOps Engineer
# 785737                                   CRM Data Analyst
# 785738                     Commercial Analyst - Start Now
# ...

# %%
#lets drop the duplicate rows in the entire df_filled with drop_duplicates()

# %%
df_unique = df_filled # lets use another datframe called as unique and perform the operartio on that
df_unique = df_unique.drop_duplicates()

# %%
df_unique
# Out:
#              job_title_short  \
# 0       Senior Data Engineer
# 1               Data Analyst
# 2              Data Engineer
# 3              Data Engineer
# 4              Data Engineer
# ...                      ...
# 785736     Software Engineer
# 785737          Data Analyst
# 785738      Business Analyst
# 785739         Data Engineer
# 785740     Software Engineer
#
#                                                 job_title  \
# 0       Senior Clinical Data Engineer / Principal Clin...
# 1                                            Data Analyst
# 2       Data Engineer/Scientist/Analyst, Mid or Senior...
# 3       LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4                                  Data Engineer- Sr Jobs
# ...                                                   ...
# 785736                                    DevOps Engineer
# 785737                                   CRM Data Analyst
# 785738                     Commercial Analyst - Start Now
# ...

# %%
len_droped = len(df_filled)-len(df_unique)
len_droped
# Out:
# 101

# %%
#now lets drop repetitive jobs from the same company    now we have drop duplicate rows but now we have tp specify the columns to be used 
df_unique = df_unique.drop_duplicates(['job_title','company_name'])

# %%
df_unique
# Out:
#              job_title_short  \
# 0       Senior Data Engineer
# 1               Data Analyst
# 2              Data Engineer
# 3              Data Engineer
# 4              Data Engineer
# ...                      ...
# 785735  Senior Data Engineer
# 785736     Software Engineer
# 785737          Data Analyst
# 785738      Business Analyst
# 785740     Software Engineer
#
#                                                 job_title  \
# 0       Senior Clinical Data Engineer / Principal Clin...
# 1                                            Data Analyst
# 2       Data Engineer/Scientist/Analyst, Mid or Senior...
# 3       LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4                                  Data Engineer- Sr Jobs
# ...                                                   ...
# 785735                               Senior Data Engineer
# 785736                                    DevOps Engineer
# 785737                                   CRM Data Analyst
# ...
